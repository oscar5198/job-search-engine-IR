# %% [markdown]
# ### PyAgrum Demo

# %% [markdown]
# Import the PyAgrum package

# %%
# !pip install pyagrum
import pyagrum as gum
# Out:
# Requirement already satisfied: pyagrum in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from pyagrum) (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from pyagrum) (3.10.8)
# Requirement already satisfied: pydot in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from pyagrum) (4.0.1)
# Requirement already satisfied: scikit-learn>=1.7 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from pyagrum) (1.7.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from scikit-learn>=1.7->pyagrum) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from scikit-learn>=1.7->pyagrum) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from scikit-learn>=1.7->pyagrum) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from matplotlib->pyagrum) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\oscar\miniconda3\envs\agrum\lib\site-packages (from python-dateutil>=2.7->matplotlib->pyagrum) (1.17.0)

# %% [markdown]
# Create an empty BN network

# %%
# Create an empty Bayesian network
bn = gum.BayesNet('Demo')
print(bn)
# Out:
# BN{nodes: 0, arcs: 0, domainSize: 1, dim: 0, mem: 0o}

# %% [markdown]
# ### Create the variables
#
# pyAgrum provides 4 types of variables :
#
# - LabelizedVariable
# - RangeVariable
# - IntegerVariable
# - DiscretizedVariable

# %%
s=bn.add(gum.LabelizedVariable('Smoking','Smoking', ['no','yes']))
c=bn.add(gum.LabelizedVariable('Lung_Cancer','Lung_Cancer', ['no','yes']))
b=bn.add(gum.LabelizedVariable('Bronchitis','Bronchitis', ['no','yes']))
d=bn.add(gum.LabelizedVariable('Dyspnoea','Dyspnoea', ['no','yes']))
print(s)
print(c)
print(b)
print(d)
print(bn)
# Out:
# 0
# 1
# 2
# 3
# BN{nodes: 4, arcs: 0, domainSize: 16, dim: 4, mem: 64o}

# %% [markdown]
# ### Create arcs

# %%
# Define the edges
bn.addArc(s,c)
bn.addArc(s,b)
bn.addArc(b,d)
bn.addArc(c,d)
print(bn)
# Out:
# BN{nodes: 4, arcs: 4, domainSize: 16, dim: 9, mem: 144o}

# %%
for link in [(s,c),(s,b),(b,d),(c,d)]:
    bn.addArc(*link)
print(bn)
# Out:
# BN{nodes: 4, arcs: 4, domainSize: 16, dim: 9, mem: 144o}

# %% [markdown]
# pyAgrum provides tools to display <tt>bn</tt> in more user-frendly fashions. <br/>Notably, <tt>pyAgrum.lib</tt> is a set of tools written in pyAgrum to help using aGrUM in python. <tt>pyAgrum.lib.notebook</tt> adds dedicated functions for iPython notebook.

# %%
# Import Jupyter Notebook helpers for visualization
import pyagrum.lib.notebook as gnb
gnb.showBN(bn)

# %% [markdown]
# ### Create the probability tables
#
# Once the network topology is constructed, we must initialize the conditional probability tables (CPT) distributions.
# Each CPT is considered as a Potential object in pyAgrum. There are several ways to fill such an object.<br/>
#
# To get the CPT of a variable, use the cpt method of your BayesNet instance with the variable's id as parameter.<br/>
#
# Now we are ready to fill in the parameters of each node in our network.

# %%
bn.cpt(s).fillWith([0.5,0.5])
# Out:
# (pyagrum.Tensor@0000013FA4298470)
#   Smoking          |
# no       |yes      |
# ---------|---------|
#  0.5000  | 0.5000  |

# %%
bn.cpt(c)[:]=[ [0.99,0.01],[0.9,0.1]]
bn.cpt(c)
# Out:
# (pyagrum.Tensor@0000013FA4298050)
#       ||  Lung_Cancer      |
# Smokin||no       |yes      |
# ------||---------|---------|
# no    || 0.9900  | 0.0100  |
# yes   || 0.9000  | 0.1000  |

# %%
bn.cpt(b)[:]=[ [0.7,0.3],[0.4,0.6]]
bn.cpt(b)
# Out:
# (pyagrum.Tensor@0000013FA4298010)
#       ||  Bronchitis       |
# Smokin||no       |yes      |
# ------||---------|---------|
# no    || 0.7000  | 0.3000  |
# yes   || 0.4000  | 0.6000  |

# %%
bn.cpt(d)[{'Lung_Cancer': 0, 'Bronchitis': 0}] = [0.9, 0.1]
bn.cpt(d)[{'Lung_Cancer': 0, 'Bronchitis': 1}] = [0.2, 0.8]
bn.cpt(d)[{'Lung_Cancer': 1, 'Bronchitis': 0}] = [0.3, 0.7]
bn.cpt(d)[{'Lung_Cancer': 1, 'Bronchitis': 1}] = [0.1, 0.9]
bn.cpt(d)
# Out:
# (pyagrum.Tensor@0000013FA4297DD0)
#              ||  Dyspnoea         |
# Bronch|Lung_C||no       |yes      |
# ------|------||---------|---------|
# no    |no    || 0.9000  | 0.1000  |
# yes   |no    || 0.2000  | 0.8000  |
# no    |yes   || 0.3000  | 0.7000  |
# yes   |yes   || 0.1000  | 0.9000  |

# %%
# See the posteriors
gnb.showInference(bn)

# %% [markdown]
# ### Inference
#
# We have to choose an inference engine to perform calculations for us. Many inference engines are currently available in pyAgrum:
#
# - **Exact inference**, particularly :
#     - `gum.LazyPropagation` : an exact inference method that transforms the Bayesian network into a hypergraph called a join tree or a junction tree. This tree is constructed in order to optimize inference computations.
#     - others: `gum.VariableElimination`, `gum.ShaferShenoy`, ...
#
# - **Samplig Inference** : approximate inference engine using sampling algorithms to generate a sequence of samples from the joint probability distribution (`gum.GibbSSampling`, etc.)
# - **Loopy Belief Propagation** : approximate inference engine using inference algorithm exact for trees but not for DAG

# %%
ie = gum.LazyPropagation(bn)

# %% [markdown]
# scenario 1: we know that patient was a smoker, see the likelihood of lung cancer and bronchitis
#
# scenario 2: we also observe that no dysponea

# %%
# Scenario 1
gnb.showInference(bn,evs={'Smoking':'yes'})

# %%
ie.setEvidence({'Smoking':'yes'})
ie.makeInference()
ie.posterior(c)
# Out:
# (pyagrum.Tensor@0000013FA45EBBF0)
#   Lung_Cancer      |
# no       |yes      |
# ---------|---------|
#  0.9000  | 0.1000  |

# %%
ie.posterior(b)
# Out:
# (pyagrum.Tensor@0000013FA45EBD90)
#   Bronchitis       |
# no       |yes      |
# ---------|---------|
#  0.4000  | 0.6000  |

# %%
# Scenario 2
gnb.showInference(bn,evs={'Smoking':'yes', 'Dyspnoea':'no'})

# %%
ie.setEvidence({'Smoking':'yes', 'Dyspnoea':'no'})
ie.makeInference()
ie.posterior(c)
# Out:
# (pyagrum.Tensor@0000013FA45ECD10)
#   Lung_Cancer      |
# no       |yes      |
# ---------|---------|
#  0.9600  | 0.0400  |

# %%
ie.posterior(b)
# Out:
# (pyagrum.Tensor@0000013FA45E7C70)
#   Bronchitis       |
# no       |yes      |
# ---------|---------|
#  0.7467  | 0.2533  |

# %% [markdown]
# ### Save BN
#
# Now our BN is complete. It can be saved in different format :
# bif|dsl|net|bifxml|o3prm|uai|xdsl

# %%
gum.saveBN(bn,"Demo.net")
